# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('cleandata.csv')

# %%
#divide the data into X and y
X=df.drop(columns=['Outcome'])
y=df[['Outcome']]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X=pd.DataFrame(data=sc.fit_transform(X),columns=X.columns)

# %%
#divide into train and test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=0,stratify=y)

# %%
print(y_train['Outcome'].value_counts())
print(y_test['Outcome'].value_counts())
# Out:
# Outcome
# 0    450
# 1    241
# Name: count, dtype: int64
# Outcome
# 0    50
# 1    27
# Name: count, dtype: int64

# %%
pip install imblearn
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Collecting imbalanced-learn (from imblearn)
#   Downloading imbalanced_learn-0.14.2-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: numpy<3,>=1.25.2 in C:\Users\tejas\AppData\Local\Programs\Python\Python314\Lib\site-packages (from imbalanced-learn->imblearn) (2.4.6)
# Requirement already satisfied: scipy<2,>=1.11.4 in C:\Users\tejas\AppData\Local\Programs\Python\Python314\Lib\site-packages (from imbalanced-learn->imblearn) (1.17.1)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in C:\Users\tejas\AppData\Local\Programs\Python\Python314\Lib\site-packages (from imbalanced-learn->imblearn) (1.9.0)
# Collecting sklearn-compat<0.2,>=0.1.6 (from imbalanced-learn->imblearn)
#   Downloading sklearn_compat-0.1.6-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: joblib<2,>=1.2.0 in C:\Users\tejas\AppData\Local\Programs\Python\Python314\Lib\site-packages (from imbalanced-learn->imblearn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in C:\Users\tejas\AppData\Local\Programs\Python\Python314\Lib\site-packages (from imbalanced-learn->imblearn) (3.6.0)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\tejas\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn<2,>=1.4.2->imbalanced-learn->imblearn) (2.22.1)
# Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Downloading imbalanced_learn-0.14.2-py3-none-any.whl (236 kB)
# Downloading sklearn_compat-0.1.6-py3-none-any.whl (22 kB)
# Installing collected packages: sklearn-compat, imbalanced-learn, imblearn
#
#    ---------------------------------------- 0/3 [sklearn-compat]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ---------------------------------------- 3/3 [imblearn]
#
# Successfully installed imbalanced-learn-0.14.2 imblearn-0.0 sklearn-compat-0.1.6
# Note: you may need to restart the kernel to use updated packages.

# %%
#balance the data
from imblearn.over_sampling import SMOTE
smote=SMOTE(random_state=42)
X-resampled,y_resampled=smote.fit_resample(X_train,y_train)
